# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruskin/inst808_fall_2025_final_project/blob/main/inst_808_final_project_get_facebook_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code for grabbing Facebook ads from Meta Ad Library API

# %%
# Optional code block for mounting your Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install package for handling Meta Ad Library API
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)

# %%
import requests

# Run this code for consecutive time frames, each time grabbing chunk of 1500-3000 ads from the API (depending on what the API allows).
# Use "next" field of returned JSON to get the next API url, and paste into below line
api_url= 'https://graph.facebook.com/v24.0/ads_archive?fields=ad_delivery_start_time,ad_delivery_stop_time,ad_creative_bodies&limit=1500&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=US&search_page_ids=925007000949719&access_token=&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalU1TmpZAME1qb3lNRGs1TkRnNE56ZA3pOamd3TmpJeQZDZD'
#api_url = 'https://graph.facebook.com/v24.0/ads_archive?limit=1000&ad_type=POLITICAL_AND_ISSUE_ADS&fields=ad_delivery_start_time,ad_delivery_stop_time,ad_creative_bodies&ad_active_status=ALL&ad_reached_countries=US&search_terms=ExxonMobil&access_token=&after=c2NyYXBpbmdfY3Vyc29yOk1UVTFPVEUwT1RVeU1UbzBOVFl5TmpJek5URTJNVFkzTkRjPQZDZD'
try:
    # Make the GET request
    response = requests.get(api_url)

    # Check for successful response (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        print("Data retrieved successfully:")
        print(data)
    else:
        print(f"Error: API request failed with status code {response.status_code}")
        print(response.text) # Print the error message if available
except requests.exceptions.RequestException as e:
    print(f"An error occurred during the request: {e}")
# Out:
# Data retrieved successfully:
# {'data': [{'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2188364951454722'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-26', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2221573001281681'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2328176834099584'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-27', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2355253371249333'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-26', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2408501606061371'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2423569087965109'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2582485818468281'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '301362680693434'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-26', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '359669954920003'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-26', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '360385001580275'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '404237956963776'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-27', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '481947429256920'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '1453067184833010'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '468397880382411'}, {'ad_delivery_start_time': '2019-08-25', 'ad_delivery_stop_time': '2019-08-25', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '498771537629247'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '519755898794249'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-28', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '2380595658847011'}, {'ad_delivery_start_time': '2019-08-24', 'ad_delivery_stop_time': '2019-08-26', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '361839394744769'}, {'ad_delivery_start_time': '2019-08-23', 'ad_delivery_stop_time': '2019-08-27', 'ad_creative_bodies': ["This content was removed because it didn't follow our Advertising Standards."], 'id': '3688487671 ...

# %%
# Save json file just in case
import json

data_path = '/content/drive/My Drive/INST808/'
file_path = os.path.join(data_path, 'new_output8.json')

with open(file_path, 'w') as f:
  json.dump(data, f, indent=4)

# %%
# Create df for the chunk of ads and start dates. Save to file
import pandas as pd
import os


data1 = data['data']
ads = [item['ad_creative_bodies'] for item in data1 if 'ad_creative_bodies' in item]
starts = [item['ad_delivery_start_time'] for item in data1 if 'ad_creative_bodies' in item]
results = pd.DataFrame(starts, columns = ['start'])
results['ad'] = ads
print(results)

file_path = os.path.join(data_path, 'ads8.tsv')
results.to_csv(file_path, sep="\t", index=False)
# Out:
#            start                                                 ad
# 0     2019-08-23  [This content was removed because it didn't fo...
# 1     2019-08-23  [This content was removed because it didn't fo...
# 2     2019-08-23  [This content was removed because it didn't fo...
# 3     2019-08-24  [This content was removed because it didn't fo...
# 4     2019-08-23  [This content was removed because it didn't fo...
# ...          ...                                                ...
# 1495  2019-08-23  [This content was removed because it didn't fo...
# 1496  2019-08-23  [This content was removed because it didn't fo...
# 1497  2019-08-23  [This content was removed because it didn't fo...
# 1498  2019-08-24  [This content was removed because it didn't fo...
# 1499  2019-08-23  [This content was removed because it didn't fo...
#
# [1500 rows x 2 columns]
