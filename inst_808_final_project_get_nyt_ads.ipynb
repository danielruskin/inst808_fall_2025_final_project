# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruskin/inst808_fall_2025_final_project/blob/main/inst_808_final_project_get_nyt_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Code for running OCR on NYT ad PDFs that were downloaded from ProQuest

# %%
# Optional code block for mounting your Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install packages to run ocr
# !sudo apt install -y tesseract-ocr
# !pip install pytesseract pdf2image
# !apt install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 1s (253 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 121703 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# ...

# %%
import pandas as pd
import os
from pdf2image import convert_from_path
import pytesseract

# %%
data_path = '/content/drive/My Drive/Courses/INST808/nyt_ads'
ads_text = [] # create list of text for all ads, where each element represents the pages of one ad
for f in os.listdir(data_path): # go through each of the 76 pdfs
  pages = convert_from_path(os.path.join(data_path, f), dpi=300) # convert file to image
  text = [] # add one elemnt in list for each page in the pdf
  for i, image in enumerate(pages): # for every page...
    text.append(pytesseract.image_to_string(image)) # use pytesseract to extract text from image
    text.append(text)
  ads_text.append(text) # append to list of text for all ads
  print(text)
# Out:
# ['Display Ad 14 -- No Title ; /\nNew York Times (1923-); Aug 3, 2006; ProQuest Historical Newspapers: The New York Times with Index\npg. A21\n\nChanging the game\n\nResearch into new emissions-reducing technologies\ncould transform our energy future.\n\nSupplying energy to meet the needs of\ngrowing economies while reducing green-\nhouse gas emissions is a global challenge\nwe all face.\n\nBy 2030, experts predict that the world\nwill require about 60 percent more energy\nthan in 2000. Economic growth in develop-\ning countries will account for most of this\nincrease.\n\nAs a result, greenhouse gas emissions\nare predicted to increase too, with develop-\ning countries account-\ning for about 85 percent\nof carbon dioxide emis-\nsions growth between\n2000 and 2030.\n\nTo meet this chal-\nlenge, we need practi-\ncal solutions. Greater\nenergy efficiency is one\nof them, and it can have a significant impact.\nBy more effectively using fossil fuels, we can\nreduce the growth in emissions
# ...

# %%
print(ads_text)
# Out:
# [['Display Ad 14 -- No Title ; /\nNew York Times (1923-); Aug 3, 2006; ProQuest Historical Newspapers: The New York Times with Index\npg. A21\n\nChanging the game\n\nResearch into new emissions-reducing technologies\ncould transform our energy future.\n\nSupplying energy to meet the needs of\ngrowing economies while reducing green-\nhouse gas emissions is a global challenge\nwe all face.\n\nBy 2030, experts predict that the world\nwill require about 60 percent more energy\nthan in 2000. Economic growth in develop-\ning countries will account for most of this\nincrease.\n\nAs a result, greenhouse gas emissions\nare predicted to increase too, with develop-\ning countries account-\ning for about 85 percent\nof carbon dioxide emis-\nsions growth between\n2000 and 2030.\n\nTo meet this chal-\nlenge, we need practi-\ncal solutions. Greater\nenergy efficiency is one\nof them, and it can have a significant impact.\nBy more effectively using fossil fuels, we can\nreduce the growth in emission
# ...

# %%
results = pd.DataFrame({"text": ads_text})
results.head()
# Out:
#                                                 text
# 0  [Display Ad 14 -- No Title ; /\nNew York Times...
# 1  [Display Ad 8 -- No Title\n\nNew York Times (1...
# 2  [Display Ad 7 -- No Title\n\nNew York Times (1...
# 3  [Display Ad 16 -- No Title\nNew york Times (19...
# 4  [Display Ad 6 -- No Title\nNew York Times (192...

# %%
# Save ads to file
file_path = os.path.join('/content/drive/My Drive/Courses/INST808/', 'nyt_ads.tsv')
results.to_csv(file_path, sep="\t", index=False)
